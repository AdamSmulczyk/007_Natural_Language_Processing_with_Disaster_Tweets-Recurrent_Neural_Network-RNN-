# %% [markdown]
# # Author Details:
# - Name: Adam Smulczyk
# - Email: adam.smulczyk@gmail.com
# - Profile: [Github](https://github.com/AdamSmulczyk)
# - [Github Repository](https://github.com/AdamSmulczyk/ML_Project_001)

# %% [markdown]
# <a id="1.2"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> Table of Contents ℹ️</div>

# %% [markdown]
# <a id="toc"></a>
# - [I. PLANNING](#I)
#     - [I.1 Introduction](#I.1)
#     - [I.2 Dataset Description](#I.2)
#     - [I.3 Project assumptions](#I.3)
#         - [I.3.1 Assessing the scope](#I.3.1)
#         - [I.3.2 Success metric](#I.3.2)
#         - [I.3.3 Feasibility  of the ML application](#I.3.3)
# - [II.DATA COLLECTION AND PREPARATION](#II)
#     - [II.1 Import libraries and data files](#II.1)
#     - [II.2 Exploratory Data Analysis (EDA)](#II.2)
#         - [II.2.1 Reading Data & Target Class Distribution](#II.2.1)
#         - [II.2.2 Missing values](#II.2.2)
#         - [II.2.3 Class distribution](#II.2.3)
#         - [II.2.4 Analysis number of characters and words in tweet](#II.2.4)
#             - [II.2.4.1 Number of characters in tweet](#II.2.4.1)
#             - [II.2.4.2 Number of words in tweet](#II.2.4.2)
#             - [II.2.4.3 Average word length in tweet](#II.2.4.3)
#         - [II.2.5 Analysis of the top keywords](#II.2.5)
#             - [II.2.5.1 Top 20 keywords](#II.2.5.1)
#             - [II.2.5.1 20 most common words in tweets](#II.2.5.2)
#             - [II.2.5.1 Top 20 keywords](#II.2.5.1)
#         - [II.2.6 Top 20 locations](#II.2.6)
# - [III DATA PRE-PROCESSING (data cleaning)](#III)
#     - [III.1 Filling nulls](#III.1)
#     - [III.2 Cleaning text](#III.2)
# - [IV DATA PROCESSING](#IV)
#     - [IV.1 Split training and valdiation set](#IV.1)
#     - [IV.2 Text processeding](#IV.2)
# - [V MODEL ENGINEERING](#V)
#     - [V.1 Model 1](#V.1)
#         - [V.1.1 Model 1 - Evaluation](#V.1.1)
#     - [V.2 Model 2](#V.2)
#         - [V.2.1 Model 2 - Evaluation](#V.2.1)
# - [VI CONCLUSION](#VI)

# %% [markdown]
#  ### <a id="I.1"></a><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.1 Introduction</p>

# %% [markdown]
# **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">Twitter</mark>** has become an important communication channel in times of emergency.
# The ubiquitousness of smartphones enables people to announce an emergency they’re observing in real-time. Because of this, more agencies are interested in programatically monitoring Twitter (i.e. disaster relief organizations and news agencies).
#
# But, it’s not always clear whether a person’s words are actually announcing a disaster. Take this example:
# The author explicitly uses the word “ABLAZE” but means it metaphorically. This is clear to a human right away, especially with the visual aid. But it’s less clear to a machine.
#
# Disclaimer: The dataset for this competition contains text that may be considered profane, vulgar, or offensive.
#
#
# Text Classification is a process involved in Sentiment Analysis. It is classification of peoples opinion or expressions into different sentiments. Sentiments include Positive, Neutral, and Negative, Review Ratings and Happy, Sad. Sentiment Analysis can be done on different consumer centered industries to analyse people's opinion on a particular product or subject.

# %% [markdown]
#  ### <a id="I.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.2 Dataset Description</p>

# %% [markdown]
# Each sample in the train and test set has the following information:
#
# * The text of a tweet
# * A keyword from that tweet (although this may be blank!)
# * The location the tweet was sent from (may also be blank)
#
# Columns
# * <code>id</code> - a unique identifier for each tweet
# * <code>text</code> - the text of the tweet
# * <code>location</code> - the location the tweet was sent from (may be blank)
# * <code>keyword</code> - a particular keyword from the tweet (may be blank)
# * <code>target</code> - in train.csv only, this denotes whether a tweet is about a real disaster (1) or not (0)

# %% [markdown]
#  ### <a id="I.3"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3 Project assumptions 🎯</p>

# %% [markdown]
#  ### <a id="I.3.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.1 Assessing the scope</p>

# %% [markdown]
# The entire project was done in Python, using Jupyter.
# You’re challenged to build a machine learning model that predicts which Tweets are about real disasters and which one’s aren’t. You’ll have access to a dataset of 10,000 tweets that were hand classified.
# You are predicting whether a given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.

# %% [markdown]
#  ### <a id="I.3.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.2 Success metric</p>

# %% [markdown]
# Submissions are evaluated using **<mark style="background-color:#3b3745;color:white;border-radius:5px;opacity:1.0">F1</mark>** between the predicted and expected answers.
#
# F1 is calculated as follows:
# ![image.png](attachment:image.png)
#
# * <code>True Positive [TP]</code> = your prediction is 1, and the ground truth is also 1 - you predicted a positive and that's true!
# * <code>False Positive [FP]</code> = your prediction is 1, and the ground truth is 0 - you predicted a positive, and that's false.
# * <code>False Negative [FN]</code> = your prediction is 0, and the ground truth is 1 - you predicted a negative, and that's false.

# %% [markdown]
#  ### <a id="I.3.3"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">I.3.3 Feasibility  of the ML application</p>

# %% [markdown]
# The feasibility of the project plan should be assessed to decide whether you are able to build a reliable predictive model with such a small sample of data. Or, can we get new data?
#
# Feature engineering will be used for this purpose to obtain a more complete set of predictive attributes. An additional aspect that will affect the assessment of the project feasibility is the provided test data set, which will be used to verify the quality of the obtained predictive model.
#
# Data analysis, feature engineering ideas for NLP, cleaning and text processing ideas, baseline BERT model or test set with labels.

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="II"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700">II <span style='color:#CDA63A'>|</span>DATA COLLECTION AND PREPARATION 👨‍💻</div>

# %% [markdown]
#  ### <a id="II.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.1 Import libraries and data files💾</p>

# %%
import re
import os
import sys
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
import warnings

# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# CONFIGURATIONS
# ------------------------------------------------------
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
pd.options.display.max_colwidth = 1000
# pd.options.display.precision = 5
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
#  ### <a id="II.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2 Exploratory Data Analysis (EDA)📊</p>

# %% [markdown]
#  ### <a id="II.2.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.1 Reading Data & Target Class Distribution 📚</p>

# %%
print('Training Set Shape = {}'.format(train.shape))
print('Training Set Memory Usage = {:.2f} MB'.format(train.memory_usage().sum() / 1024**2))
print('Test Set Shape = {}'.format(test.shape))
print('Test Set Memory Usage = {:.2f} MB'.format(test.memory_usage().sum() / 1024**2))
# Out:
# Training Set Shape = (7613, 5)
# Training Set Memory Usage = 0.29 MB
# Test Set Shape = (3263, 4)
# Test Set Memory Usage = 0.10 MB

# %%
train.head(10)
# Out:
#    id keyword location  \
# 0   1     NaN      NaN
# 1   4     NaN      NaN
# 2   5     NaN      NaN
# 3   6     NaN      NaN
# 4   7     NaN      NaN
# 5   8     NaN      NaN
# 6  10     NaN      NaN
# 7  13     NaN      NaN
# 8  14     NaN      NaN
# 9  15     NaN      NaN
#
#                                                                                                                                     text  \
# 0                                                                  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1                                                                                                 Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3                                                                      13,000 people receive #wildfires evacuation orders in California
# ...

# %%
train["length"] = train["text"].apply(lambda x : len(x))
print("         Length stat")
print(train["length"].describe())
print()
# Out:
#          Length stat
# count    7613.000000
# mean      101.037436
# std        33.781325
# min         7.000000
# 25%        78.000000
# 50%       107.000000
# 75%       133.000000
# max       157.000000
# Name: length, dtype: float64

# %% [markdown]
#  ### <a id="II.2.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.2 Missing values</p>

# %%
# Check the data
train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> There are missing values in the train and test dataset but in this case this columns are not imortant.
# </ul>
# </div>

# %% [markdown]
# ### <a id="II.2.3"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.3 Class distribution</p>

# %%
# extracting the number of examples of each class
Real_len = train[train['target'] == 1].shape[0]
Not_len = train[train['target'] == 0].shape[0]

# %%
chart = sns.countplot(x='target',
              data=train,
              palette='viridis_r')
plt.title('Class Distribution')
chart.bar_label(chart.containers[0])

plt.ylabel('Number of examples')
plt.title('Propertion of examples')
plt.show()

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> Classes are almost equally separated so they don't require any stratification by target in cross-validation.
# </ul>
# </div>

# %% [markdown]
# ### <a id="II.2.4"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.4 Analysis number of characters and words in tweet</p>

# %% [markdown]
# ### <a id="II.2.4.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.4.1 Number of characters in tweet</p>

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
tweet_len=train[train['target']==1]['text'].str.len()
sns.distplot(tweet_len.map(lambda x: np.mean(x)),ax=ax1,color='blue')
ax1.set_title('disaster')
tweet_len=train[train['target']==1]['text'].str.len()
sns.distplot(tweet_len.map(lambda x: np.mean(x)),ax=ax2,color='green')
ax2.set_title('Not disaster')
fig.suptitle('Number of characters in tweet')
# Out:
# Text(0.5, 0.98, 'Number of characters in tweet')

# %% [markdown]
# ### <a id="II.2.4.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.4.2 Number of words in tweet</p>

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
tweet_len=train[train['target']==1]['text'].str.split().map(lambda x: len(x))
sns.distplot(tweet_len.map(lambda x: np.mean(x)),ax=ax1,color='blue')
ax1.set_title('disaster')
tweet_len=train[train['target']==0]['text'].str.split().map(lambda x: len(x))
sns.distplot(tweet_len.map(lambda x: np.mean(x)),ax=ax2,color='green')
ax2.set_title('Not disaster')
fig.suptitle('Words in a tweet')
# Out:
# Text(0.5, 0.98, 'Words in a tweet')

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> These are the means and standard deviations of the above distibutions.
# </ul>
# </div>

# %% [markdown]
# ### <a id="II.2.4.3"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.4.3 Average word length in tweet</p>

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
word=train[train['target']==1]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax1,color='blue')
ax1.set_title('disaster')
word=train[train['target']==0]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax2,color='green')
ax2.set_title('Not disaster')
fig.suptitle('Average word length in each tweet')
# Out:
# Text(0.5, 0.98, 'Average word length in each tweet')

# %% [markdown]
# ### <a id="II.2.5"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5 Analysis of the top keywords</p>

# %% [markdown]
# ### <a id="II.2.5.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.1 Top 20 keywords</p>

# %%
top20_keywords_train = train.groupby('keyword')['keyword'].count().reset_index(name='count').sort_values(by='count',ascending=False).head(20)
top20_keywords_test = test.groupby('keyword')['keyword'].count().reset_index(name='count').sort_values(by='count',ascending=False).head(20)



fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,6))

ax1 = sns.barplot(data=top20_keywords_train,x='keyword',y='count', palette='viridis',ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
ax1.set_title('Top 20 keywords in the train data',fontsize=20)

ax2 = sns.barplot(data=top20_keywords_test,x='keyword',y='count', palette='viridis',ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=90)
ax2.set_title('Top 20 keywords in the test data',fontsize=20)

# plt.suptitle('Top 20 keywords',fontsize=25)
plt.tight_layout()

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> The top keywords in the train and test datasets are rather different.
# <li> This means that the events in the two datasets may not be so similar.
# </ul>
# </div>

# %% [markdown]
# ### <a id="II.2.5.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.5.2 20 most common words in tweets</p>

# %%
num_words = Counter(" ".join(train["text"]).split()).most_common(20)

x,y = zip(*num_words)

plt.bar(x,y,color='mediumslateblue')#mediumslateblue lightsteelblue
plt.xticks(rotation=90)
plt.title("20 most common words in tweets",size=18)
plt.ylabel("counts",size=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> Most common words in disaster and non disaster tweets.
# </ul>
# </div>

# %%
data_disaster = train[train['target'] == 1]
data_nondisaster = train[train['target'] == 0]

num_words_disaster = Counter(" ".join(data_disaster["text"]).split()).most_common(20)
num_words_nondisaster = Counter(" ".join(data_nondisaster["text"]).split()).most_common(20)

x1,y1 = zip(*num_words_disaster)
x2,y2 = zip(*num_words_nondisaster)

fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,6))

ax1.bar(x1,y1,color='green')
ax1.tick_params(axis='x',rotation=90)
ax1.title.set_text("20 most common words in disaster tweets")
ax1.title.set_size(16)

ax2.bar(x2,y2,color='blue')
ax2.tick_params(axis='x',rotation=90)
ax2.title.set_text("20 most common words in non-disaster tweets")
ax2.title.set_size(16)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> As shown in the above plots, some top words (like via) are shared in the two categories.
# <li> There are also non relevant words, like cant and dont.
# </ul>
# </div>

# %% [markdown]
# ### <a id="II.2.6"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">II.2.6 Top 20 locations</p>

# %%
top20_locations_train = train.groupby('location')['location'].count().reset_index(name='count').sort_values(by='count',ascending=False).head(20)
top20_locations_test = test.groupby('location')['location'].count().reset_index(name='count').sort_values(by='count',ascending=False).head(20)


fig, (ax1,ax2) = plt.subplots(ncols=2,figsize=(12,6))

ax1 = sns.barplot(data=top20_locations_train,x='location',y='count',ax=ax1, palette='viridis')
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
ax1.set_title('Top 20 locations in the train data',fontsize=20)

ax2 = sns.barplot(data=top20_locations_test,x='location',y='count', ax=ax2, palette='viridis')
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=90)
ax2.set_title('Top 20 locations in the test data',fontsize=20)

plt.tight_layout()

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Conclusions:
# <li> The most occurring locations are in the USA.
# </ul>
# </div>

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="III"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700">III <span style='color:#CDA63A'>|</span>DATA PRE-PROCESSING</div>

# %% [markdown]
# ### <a id="III.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.1 Filling nulls</p>

# %%
train.isnull().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
# Fill missing data (for example: we can fill missing location and keyword values with "Unknown")
train['location'] = train['location'].fillna('Unknown')
train['keyword'] = train['keyword'].fillna('Unknown')

# %% [markdown]
# ### <a id="III.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">III.2 Cleaning text</p>

# %%
# Text cleaning function
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'http\S+', '', text)  # Remove links
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Apply text cleaning
train['cleaned_text'] = train['text'].apply(clean_text)

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="IV"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700">IV <span style='color:#CDA63A'>|</span>DATA PROCESSING 🛠️</div>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import tensorflow as tf
from tensorflow import keras
import keras_nlp
from keras.optimizers import Adam
from sklearn.metrics import f1_score

# %%
batch_size = 32
num_training_examples = train.shape[0]
train_split = 0.8
val_split = 0.2
state=42
steps_per_epoch = int(num_training_examples)*train_split // batch_size

epochs = 2
auto = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ### <a id="IV.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">IV.1 Text processeding</p>

# %%
# Stop words and stemming
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def preprocess_text(text):
    words = text.split()
    words = [stemmer.stem(word) for word in words if word not in stop_words]
    return ' '.join(words)

# Create a column with preprocessed text
train['processed_text'] = train['cleaned_text'].apply(preprocess_text)
# Preview the processed data
train[['text', 'cleaned_text', 'processed_text']].head()
# Out:
#                                                                                                                                     text  \
# 0                                                                  Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# 1                                                                                                 Forest fire near La Ronge Sask. Canada
# 2  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 3                                                                      13,000 people receive #wildfires evacuation orders in California
# 4                                               Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
#
#                                                                                                                          cleaned_text  \
# ...

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# Initialise distilbert-base-uncased and create a function for tokenisation
# </ul>
# </div>

# %% [markdown]
# ### <a id="IV.2"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">IV.2 Split training and valdiation set</p>

# %%
X = train["processed_text"]
y = train["target"]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=val_split, random_state=state)

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="V"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700">V <span style='color:#CDA63A'>|</span>MODEL ENGINEERING 🤖</div>

# %%
# Load a DistilBERT model.
preset= "distil_bert_base_en_uncased"

# Use a shorter sequence length.
preprocessor = keras_nlp.models.DistilBertPreprocessor.from_preset(preset,
                                                                   sequence_length=160,
                                                                   name="preprocessor_4_tweets"
                                                                  )
# Pretrained classifier.
classifier = keras_nlp.models.DistilBertClassifier.from_preset(preset,
                                                               preprocessor = preprocessor, 
                                                               num_classes=2)
classifier.summary()

# %% [markdown]
#  ### <a id="V.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.1 Model 1</p>

# %%
# Compile
classifier.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=Adam(learning_rate=1e-5),
    metrics=["accuracy"]
)

# Fit
history = classifier.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size, 
    epochs=epochs, 
    validation_data=(X_val, y_val)
)

# %% [markdown]
#  ### <a id="V.1.1"><p style="background-color: #636B2F;color:white;display: inline-block;padding:.6rem;border-radius:.5rem">V.1.1 Model 1 - Evaluation</p>

# %%
classifier.evaluate(X_val, y_val)

# %%
train_true = y_train.copy()
train_pred = classifier.predict(X_train)
train_pred = np.argmax(train_pred, axis=1) 

val_true = y_val.copy()
val_pred = classifier.predict(X_val)
val_pred = np.argmax(val_pred, axis=1) 

train_f1_score = f1_score(train_true, train_pred)
val_f1_score = f1_score(val_true, val_pred)

print("F1-score metric on train data == {}".format(train_f1_score))
print("F1-score metric on validation dataset == {}".format(val_f1_score))

# %%
classifier.summary()

# %%
history.history['accuracy']

# %%
history.history['val_accuracy']

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.show()

# %% [markdown]
# <a href="#toc" role="button" aria-pressed="true" >🔝Back to Table of Contents🔝</a>

# %% [markdown]
# <a id="VI"></a>
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#636B2F;
#             overflow:hidden;
#             font-weight:700">VI <span style='color:#CDA63A'>|</span>CONCLUSION 👩‍🏫</div>

# %% [markdown]
# <div style=" background-color:#EDE8D0;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: black">
# <ul>
# BERT stands for Bidirectional Encoder Representations from Transformers. BERT and other Transformer encoder architectures have been wildly successful on a variety of tasks in NLP (natural language processing). They compute vector-space representations of natural language that are suitable for use in deep learning models.
#
# The BERT family of models uses the Transformer encoder architecture to process each token of input text in the full context of all tokens before and after, hence the name: Bidirectional Encoder Representations from Transformers.
#
# BERT models are usually pre-trained on a large corpus of text, then fine-tuned for specific tasks.
# </ul>
# </div>
